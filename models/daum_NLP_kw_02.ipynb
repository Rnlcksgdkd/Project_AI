# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/project/train.csv')
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/project/test.csv')

# %%
train['comment'] = train['comment'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]', '')
test['comment'] = test['comment'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]', '')

# %%
stopwords = ['의', '가', '이', '은', '들', '는', '좀', '잘', '걍', '과', '도', '를', '자', '에', '와', '한', '하다']

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 161kB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/cd/a5/9781e2ef4ca92d09912c4794642c1653aea7607f473e156cf4d423a881a1/JPype1-1.2.1-cp37-cp37m-manylinux2010_x86_64.whl (457kB)
#      |████████████████████████████████| 460kB 56.6MB/s
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 12.7MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.12.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Installing collected packages: JPype1, beautifulsoup4, colorama, konlpy
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.2.1 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
train_list_X = train.comment.to_list()
train_list_y = train.label.to_list()
test_list_X = test.comment.to_list()
test_list_y = test.label.to_list()

# %%
len(train_list_X), len(train_list_y), len(test_list_X), len(test_list_y)
# Out:
# (28236, 28236, 4515, 4515)

# %%
import numpy as np
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# - train data

# %%
maxlen = 2000
max_words = 10000

tokenizer = Tokenizer(num_words = max_words)
tokenizer.fit_on_texts(train_list_X)
sequences = tokenizer.texts_to_sequences(train_list_X)

word_index = tokenizer.word_index
print('{}개의 고유한 토큰을 찾았습니다.'.format(len(word_index)))
# Out:
# 92581개의 고유한 토큰을 찾았습니다.

# %%
data_train = pad_sequences(sequences, maxlen = maxlen)
labels_train = np.array(train_list_y)

data_train.shape, labels_train.shape
# Out:
# ((28236, 2000), (28236,))

# %% [markdown]
# - test data

# %%
maxlen = 2000
max_words = 10000

tokenizer = Tokenizer(num_words = max_words)
tokenizer.fit_on_texts(test_list_X)
sequences = tokenizer.texts_to_sequences(test_list_X)

word_index = tokenizer.word_index
print('{}개의 고유한 토큰을 찾았습니다.'.format(len(word_index)))
# Out:
# 28775개의 고유한 토큰을 찾았습니다.

# %%
data_test = pad_sequences(sequences, maxlen = maxlen)
labels_test = np.array(test_list_y)

data_test.shape, labels_test.shape
# Out:
# ((4515, 2000), (4515,))

# %% [markdown]
# - train valid split

# %%
indices = np.arange(data_train.shape[0])
np.random.shuffle(indices)
data = data_train[indices]
labels = labels_train[indices]

# %%
training_samples = 20000

X_train = data[:training_samples]
y_train = labels[:training_samples]
X_valid = data[training_samples:]
y_valid = labels[training_samples:]

# %%
import tensorflow_hub as hub

embeddings_index = hub.load('https://tfhub.dev/google/tf2-preview/nnlm-ko-dim128-with-normalization/1')

# %%
embeddings_index([''])
# ?? 판새가 있다고?
# Out:
# <tf.Tensor: shape=(1, 128), dtype=float32, numpy=
# array([[-1.82610840e-01, -2.71886867e-03,  6.46980628e-02,
#          7.22297803e-02, -2.81831026e-02, -7.85918310e-02,
#         -1.07683223e-02, -6.43315399e-03, -1.24962814e-01,
#         -1.52119458e-01,  9.63070337e-03,  8.88594463e-02,
#          1.93727657e-01,  1.45815477e-01,  6.35704547e-02,
#          3.17381620e-02,  1.65435404e-03,  1.60897940e-01,
#          2.10208118e-01, -1.57924704e-02, -7.39542320e-02,
#          5.22503480e-02,  4.00299579e-02,  3.14177051e-02,
#          2.80258786e-02, -1.49299443e-01, -6.92114830e-02,
#         -2.37217546e-02,  1.56167224e-01,  2.65407655e-02,
#         -4.18795943e-02, -4.93632406e-02, -1.05662353e-01,
#         -8.28058198e-02,  1.40575036e-01,  1.15573458e-01,
#          8.68666023e-02,  1.96279289e-04, -8.16652104e-02,
#         -7.42786974e-02, -1.35161325e-01,  1.12149585e-02,
#         -6.37857616e-02, -2.68632248e-02, -1.37057021e-01,
#          6.78175017e-02,  1.00739345e-01, -1.09537870e-01,
#         -3.19795050e-02, -3.85839045e-02,  1.14843413e-01,
#          4.45393734e-02,  6.24007918e-02, -9.51213539e-02,
#         -1.10169761e-01, -9.95987281e-02, -1.76013455e-01,
#         -9.13780257e-02, -5.03536500e-02, -1.25879119e-03,
#          7.93028437e-03,  4.44873050e-02, -2.04193562e-01,
#          8.56719092e-02,  1.44876149e-02, -1.08214982e-01,
#          4.37472500e-02, -2.58127302e-02,  5.50313070e-02,
#          1.44614771e-01, -2.84204399e-03,  2.18808338e-01,
#          1.03121735e-01,  1.43434098e-02,  4.96666729e-02,
#          5.59506118e-02, -8.01390335e-02,  1.01030760e-01,
#         -5.18878326e-02, -6.57996312e-02, -2.67029963e-02,
#         -4.74565290e-02,  1.47818327e-01, -8.79401341e-02,
#         -3.29308584e-02, -1.44799039e-01, -5.26649393e-02,
#         -2.85646450e-02,  3.06025445e-02, -2.10159048e-02,
#         -2.11420842e-02,  1.95377995e-03, -1.03435181e-01,
#          6.95940256e-02, -3.88322584e-02, -2.78856792e-02,
#          2.54792552e-02, -4.15471196e-02,  8.30081105e-02,
#          9.12378281e-02,  7.57658109e-02, -7.48204589e-02,
#         -9.44744274e-02,  1.18503623e-01,  3.66801955e-02,
#          6.06042370e-02, -5.36423288e-02,  9.23413876e-03,
#          1.70761973e-01, -5.92693351e-02,  1.06922137e-02,
#          5.31496257e-02,  7.98736513e-02, -5.79294302e-02,
#          3.74392718e-02,  5.09414859e-02,  3.53402868e-02,
#         -1.86453313e-01, -1.34175926e-01, -8.10282975e-02,
#         -6.46690205e-02, -5.76219931e-02,  4.31964658e-02,
#         -9.92011651e-03,  1.26488999e-01, -1.21020205e-01,
#         -8.39194097e-03,  3.51430029e-02]], dtype=float32)>

# %%
embedding_dim = 128

embedding_matrix = np.zeros((max_words, embedding_dim))

for word, i in word_index.items():
  embedding_vector = embeddings_index([word])
  if i < max_words:
    if embedding_vector is not None:
      embedding_matrix[i] = embedding_vector

# %%
embedding_matrix.shape
# Out:
# (10000, 128)

# %%
from keras import models
from keras import layers

comment_model = models.Sequential()

comment_model.add(layers.Embedding(max_words,
                                   embedding_dim,
                                   input_length = maxlen))

comment_model.add(layers.LSTM(32))
comment_model.add(layers.Dropout(0.5))
comment_model.add(layers.Dense(1, activation = 'sigmoid'))

comment_model.layers[0].set_weights([embedding_matrix])
comment_model.layers[0].trainable = False

# %%
comment_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 2000, 128)         1280000
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 32)                20608
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,300,641
# Trainable params: 20,641
# Non-trainable params: 1,280,000
# _________________________________________________________________

# %%
comment_model.compile(loss = 'binary_crossentropy',
                      optimizer = 'adam',
                      metrics = ['accuracy'])

# %%
from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor = 'val_accuracy',
                   mode = 'max',
                   patience = 20,
                   verbose = 1)

# %%
from keras.callbacks import ModelCheckpoint

mc = ModelCheckpoint('/content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5',
                     monitor = 'val_accuracy',
                     mode = 'max',
                     save_best_only = True,
                     verbose = 1)

# %%
# %%time

Hist = comment_model.fit(X_train, y_train,
                         epochs = 500,
                         batch_size = 512,
                         validation_data = (X_valid, y_valid),
                         callbacks = [es, mc],
                         verbose = 1)
# Out:
# Epoch 1/500
# 40/40 [==============================] - 20s 503ms/step - loss: 0.6902 - accuracy: 0.5358 - val_loss: 0.6866 - val_accuracy: 0.5493
#
# Epoch 00001: val_accuracy improved from -inf to 0.54930, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 2/500
# 40/40 [==============================] - 19s 488ms/step - loss: 0.6861 - accuracy: 0.5504 - val_loss: 0.6847 - val_accuracy: 0.5658
#
# Epoch 00002: val_accuracy improved from 0.54930 to 0.56581, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 3/500
# 40/40 [==============================] - 19s 486ms/step - loss: 0.6842 - accuracy: 0.5572 - val_loss: 0.6828 - val_accuracy: 0.5668
#
# Epoch 00003: val_accuracy improved from 0.56581 to 0.56678, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 4/500
# 40/40 [==============================] - 20s 494ms/step - loss: 0.6818 - accuracy: 0.5652 - val_loss: 0.6812 - val_accuracy: 0.5680
#
# Epoch 00004: val_accuracy improved from 0.56678 to 0.56799, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 5/500
# 40/40 [==============================] - 20s 498ms/step - loss: 0.6814 - accuracy: 0.5656 - val_loss: 0.6808 - val_accuracy: 0.5699
#
# Epoch 00005: val_accuracy improved from 0.56799 to 0.56994, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 6/500
# 40/40 [==============================] - 20s 494ms/step - loss: 0.6786 - accuracy: 0.5742 - val_loss: 0.6800 - val_accuracy: 0.5710
#
# Epoch 00006: val_accuracy improved from 0.56994 to 0.57103, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 7/500
# 40/40 [==============================] - 20s 498ms/step - loss: 0.6768 - accuracy: 0.5753 - val_loss: 0.6794 - val_accuracy: 0.5715
#
# Epoch 00007: val_accuracy improved from 0.57103 to 0.57152, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 8/500
# 40/40 [==============================] - 20s 495ms/step - loss: 0.6743 - accuracy: 0.5781 - val_loss: 0.6787 - val_accuracy: 0.5732
#
# Epoch 00008: val_accuracy improved from 0.57152 to 0.57322, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 9/500
# 40/40 [==============================] - 20s 495ms/step - loss: 0.6734 - accuracy: 0.5810 - val_loss: 0.6780 - val_accuracy: 0.5738
#
# Epoch 00009: val_accuracy improved from 0.57322 to 0.57382, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 10/500
# 40/40 [==============================] - 20s 495ms/step - loss: 0.6718 - accuracy: 0.5893 - val_loss: 0.6772 - val_accuracy: 0.5735
#
# Epoch 00010: val_accuracy did not improve from 0.57382
# Epoch 11/500
# 40/40 [==============================] - 20s 494ms/step - loss: 0.6698 - accuracy: 0.5903 - val_loss: 0.6767 - val_accuracy: 0.5752
#
# Epoch 00011: val_accuracy improved from 0.57382 to 0.57516, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 12/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.6688 - accuracy: 0.5917 - val_loss: 0.6777 - val_accuracy: 0.5776
#
# Epoch 00012: val_accuracy improved from 0.57516 to 0.57759, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 13/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.6675 - accuracy: 0.5917 - val_loss: 0.6768 - val_accuracy: 0.5792
#
# Epoch 00013: val_accuracy improved from 0.57759 to 0.57916, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 14/500
# 40/40 [==============================] - 20s 495ms/step - loss: 0.6654 - accuracy: 0.5951 - val_loss: 0.6785 - val_accuracy: 0.5811
#
# Epoch 00014: val_accuracy improved from 0.57916 to 0.58111, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 15/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.6655 - accuracy: 0.5935 - val_loss: 0.6775 - val_accuracy: 0.5767
#
# Epoch 00015: val_accuracy did not improve from 0.58111
# Epoch 16/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.6638 - accuracy: 0.5957 - val_loss: 0.6770 - val_accuracy: 0.5834
#
# Epoch 00016: val_accuracy improved from 0.58111 to 0.58341, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 17/500
# 40/40 [==============================] - 20s 498ms/step - loss: 0.6617 - accuracy: 0.6021 - val_loss: 0.6767 - val_accuracy: 0.5817
#
# Epoch 00017: val_accuracy did not improve from 0.58341
# Epoch 18/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.6628 - accuracy: 0.5969 - val_loss: 0.6811 - val_accuracy: 0.5799
#
# Epoch 00018: val_accuracy did not improve from 0.58341
# Epoch 19/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.6615 - accuracy: 0.5975 - val_loss: 0.6774 - val_accuracy: 0.5780
#
# Epoch 00019: val_accuracy did not improve from 0.58341
# Epoch 20/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.6604 - accuracy: 0.6015 - val_loss: 0.6760 - val_accuracy: 0.5849
#
# Epoch 00020: val_accuracy improved from 0.58341 to 0.58487, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 21/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.6562 - accuracy: 0.6054 - val_loss: 0.6771 - val_accuracy: 0.5840
#
# Epoch 00021: val_accuracy did not improve from 0.58487
# Epoch 22/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.6546 - accuracy: 0.6084 - val_loss: 0.6760 - val_accuracy: 0.5891
#
# Epoch 00022: val_accuracy improved from 0.58487 to 0.58912, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 23/500
# 40/40 [==============================] - 20s 494ms/step - loss: 0.6537 - accuracy: 0.6085 - val_loss: 0.6819 - val_accuracy: 0.5867
#
# Epoch 00023: val_accuracy did not improve from 0.58912
# Epoch 24/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.6530 - accuracy: 0.6075 - val_loss: 0.6804 - val_accuracy: 0.5900
#
# Epoch 00024: val_accuracy improved from 0.58912 to 0.58997, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 25/500
# 40/40 [==============================] - 20s 498ms/step - loss: 0.6511 - accuracy: 0.6128 - val_loss: 0.6751 - val_accuracy: 0.5912
#
# Epoch 00025: val_accuracy improved from 0.58997 to 0.59119, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 26/500
# 40/40 [==============================] - 20s 494ms/step - loss: 0.6502 - accuracy: 0.6131 - val_loss: 0.6915 - val_accuracy: 0.5843
#
# Epoch 00026: val_accuracy did not improve from 0.59119
# Epoch 27/500
# 40/40 [==============================] - 20s 494ms/step - loss: 0.6513 - accuracy: 0.6123 - val_loss: 0.6735 - val_accuracy: 0.5917
#
# Epoch 00027: val_accuracy improved from 0.59119 to 0.59167, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 28/500
# 40/40 [==============================] - 20s 495ms/step - loss: 0.6476 - accuracy: 0.6155 - val_loss: 0.6736 - val_accuracy: 0.5952
#
# Epoch 00028: val_accuracy improved from 0.59167 to 0.59519, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 29/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.6437 - accuracy: 0.6191 - val_loss: 0.6748 - val_accuracy: 0.5942
#
# Epoch 00029: val_accuracy did not improve from 0.59519
# Epoch 30/500
# 40/40 [==============================] - 20s 496ms/step - loss: 1.0510 - accuracy: 0.5939 - val_loss: 1.5103 - val_accuracy: 0.4594
#
# Epoch 00030: val_accuracy did not improve from 0.59519
# Epoch 31/500
# 40/40 [==============================] - 20s 498ms/step - loss: 0.6927 - accuracy: 0.5839 - val_loss: 0.6746 - val_accuracy: 0.5822
#
# Epoch 00031: val_accuracy did not improve from 0.59519
# Epoch 32/500
# 40/40 [==============================] - 20s 498ms/step - loss: 0.6626 - accuracy: 0.6053 - val_loss: 0.6718 - val_accuracy: 0.5868
#
# Epoch 00032: val_accuracy did not improve from 0.59519
# Epoch 33/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.6606 - accuracy: 0.6047 - val_loss: 0.6702 - val_accuracy: 0.5912
#
# Epoch 00033: val_accuracy did not improve from 0.59519
# Epoch 34/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.6576 - accuracy: 0.6104 - val_loss: 0.6690 - val_accuracy: 0.5917
#
# Epoch 00034: val_accuracy did not improve from 0.59519
# Epoch 35/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.6564 - accuracy: 0.6090 - val_loss: 0.6685 - val_accuracy: 0.5922
#
# Epoch 00035: val_accuracy did not improve from 0.59519
# Epoch 36/500
# 40/40 [==============================] - 20s 495ms/step - loss: 0.6536 - accuracy: 0.6163 - val_loss: 0.6679 - val_accuracy: 0.5935
#
# Epoch 00036: val_accuracy did not improve from 0.59519
# Epoch 37/500
# 40/40 [==============================] - 20s 495ms/step - loss: 0.6524 - accuracy: 0.6158 - val_loss: 0.6679 - val_accuracy: 0.5956
#
# Epoch 00037: val_accuracy improved from 0.59519 to 0.59556, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 38/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.6501 - accuracy: 0.6165 - val_loss: 0.6679 - val_accuracy: 0.5952
#
# Epoch 00038: val_accuracy did not improve from 0.59556
# Epoch 39/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.6504 - accuracy: 0.6166 - val_loss: 0.6671 - val_accuracy: 0.5973
#
# Epoch 00039: val_accuracy improved from 0.59556 to 0.59726, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 40/500
# 40/40 [==============================] - 20s 499ms/step - loss: 0.6481 - accuracy: 0.6218 - val_loss: 0.6668 - val_accuracy: 0.5990
#
# Epoch 00040: val_accuracy improved from 0.59726 to 0.59896, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 41/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.6467 - accuracy: 0.6221 - val_loss: 0.6662 - val_accuracy: 0.6002
#
# Epoch 00041: val_accuracy improved from 0.59896 to 0.60017, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 42/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.6454 - accuracy: 0.6230 - val_loss: 0.6661 - val_accuracy: 0.5994
#
# Epoch 00042: val_accuracy did not improve from 0.60017
# Epoch 43/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.6434 - accuracy: 0.6253 - val_loss: 0.6664 - val_accuracy: 0.5987
#
# Epoch 00043: val_accuracy did not improve from 0.60017
# Epoch 44/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.6429 - accuracy: 0.6223 - val_loss: 0.6665 - val_accuracy: 0.5982
#
# Epoch 00044: val_accuracy did not improve from 0.60017
# Epoch 45/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.6410 - accuracy: 0.6273 - val_loss: 0.6654 - val_accuracy: 0.6009
#
# Epoch 00045: val_accuracy improved from 0.60017 to 0.60090, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 46/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.6394 - accuracy: 0.6281 - val_loss: 0.6647 - val_accuracy: 0.6030
#
# Epoch 00046: val_accuracy improved from 0.60090 to 0.60296, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 47/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.6371 - accuracy: 0.6287 - val_loss: 0.6657 - val_accuracy: 0.6022
#
# Epoch 00047: val_accuracy did not improve from 0.60296
# Epoch 48/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.6357 - accuracy: 0.6298 - val_loss: 0.6651 - val_accuracy: 0.6015
#
# Epoch 00048: val_accuracy did not improve from 0.60296
# Epoch 49/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.6334 - accuracy: 0.6334 - val_loss: 0.6652 - val_accuracy: 0.6021
#
# Epoch 00049: val_accuracy did not improve from 0.60296
# Epoch 50/500
# 40/40 [==============================] - 20s 498ms/step - loss: 0.6325 - accuracy: 0.6366 - val_loss: 0.6643 - val_accuracy: 0.6031
#
# Epoch 00050: val_accuracy improved from 0.60296 to 0.60308, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 51/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.6296 - accuracy: 0.6348 - val_loss: 0.6639 - val_accuracy: 0.6053
#
# Epoch 00051: val_accuracy improved from 0.60308 to 0.60527, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 52/500
# 40/40 [==============================] - 20s 495ms/step - loss: 0.6309 - accuracy: 0.6352 - val_loss: 0.6639 - val_accuracy: 0.6041
#
# Epoch 00052: val_accuracy did not improve from 0.60527
# Epoch 53/500
# 40/40 [==============================] - 20s 495ms/step - loss: 0.6283 - accuracy: 0.6382 - val_loss: 0.6635 - val_accuracy: 0.6050
#
# Epoch 00053: val_accuracy did not improve from 0.60527
# Epoch 54/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.6390 - accuracy: 0.6362 - val_loss: 0.6658 - val_accuracy: 0.5990
#
# Epoch 00054: val_accuracy did not improve from 0.60527
# Epoch 55/500
# 40/40 [==============================] - 20s 498ms/step - loss: 0.6292 - accuracy: 0.6368 - val_loss: 0.6642 - val_accuracy: 0.6021
#
# Epoch 00055: val_accuracy did not improve from 0.60527
# Epoch 56/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.6244 - accuracy: 0.6428 - val_loss: 0.6640 - val_accuracy: 0.6095
#
# Epoch 00056: val_accuracy improved from 0.60527 to 0.60952, saving model to /content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5
# Epoch 57/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.6233 - accuracy: 0.6421 - val_loss: 0.6635 - val_accuracy: 0.6051
#
# Epoch 00057: val_accuracy did not improve from 0.60952
# Epoch 58/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.6207 - accuracy: 0.6412 - val_loss: 0.6650 - val_accuracy: 0.6055
#
# Epoch 00058: val_accuracy did not improve from 0.60952
# Epoch 59/500
# 40/40 [==============================] - 20s 497ms/step - loss: 1.9432 - accuracy: 0.4807 - val_loss: 1.5698 - val_accuracy: 0.4596
#
# Epoch 00059: val_accuracy did not improve from 0.60952
# Epoch 60/500
# 40/40 [==============================] - 20s 499ms/step - loss: 1.0771 - accuracy: 0.4640 - val_loss: 0.7611 - val_accuracy: 0.4710
#
# Epoch 00060: val_accuracy did not improve from 0.60952
# Epoch 61/500
# 40/40 [==============================] - 20s 499ms/step - loss: 0.7497 - accuracy: 0.4919 - val_loss: 0.7081 - val_accuracy: 0.4960
#
# Epoch 00061: val_accuracy did not improve from 0.60952
# Epoch 62/500
# 40/40 [==============================] - 20s 498ms/step - loss: 0.7291 - accuracy: 0.5045 - val_loss: 0.7000 - val_accuracy: 0.5010
#
# Epoch 00062: val_accuracy did not improve from 0.60952
# Epoch 63/500
# 40/40 [==============================] - 20s 496ms/step - loss: 0.7168 - accuracy: 0.5124 - val_loss: 0.6952 - val_accuracy: 0.5070
#
# Epoch 00063: val_accuracy did not improve from 0.60952
# Epoch 64/500
# 40/40 [==============================] - 20s 498ms/step - loss: 0.7097 - accuracy: 0.5155 - val_loss: 0.6917 - val_accuracy: 0.5106
#
# Epoch 00064: val_accuracy did not improve from 0.60952
# Epoch 65/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.7048 - accuracy: 0.5155 - val_loss: 0.6891 - val_accuracy: 0.5406
#
# Epoch 00065: val_accuracy did not improve from 0.60952
# Epoch 66/500
# 40/40 [==============================] - 20s 500ms/step - loss: 0.7011 - accuracy: 0.5178 - val_loss: 0.6874 - val_accuracy: 0.5460
#
# Epoch 00066: val_accuracy did not improve from 0.60952
# Epoch 67/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.6973 - accuracy: 0.5258 - val_loss: 0.6860 - val_accuracy: 0.5528
#
# Epoch 00067: val_accuracy did not improve from 0.60952
# Epoch 68/500
# 40/40 [==============================] - 20s 499ms/step - loss: 0.6947 - accuracy: 0.5363 - val_loss: 0.6851 - val_accuracy: 0.5571
#
# Epoch 00068: val_accuracy did not improve from 0.60952
# Epoch 69/500
# 40/40 [==============================] - 20s 498ms/step - loss: 0.6930 - accuracy: 0.5369 - val_loss: 0.6844 - val_accuracy: 0.5597
#
# Epoch 00069: val_accuracy did not improve from 0.60952
# Epoch 70/500
# 40/40 [==============================] - 20s 499ms/step - loss: 0.6898 - accuracy: 0.5422 - val_loss: 0.6838 - val_accuracy: 0.5616
#
# Epoch 00070: val_accuracy did not improve from 0.60952
# Epoch 71/500
# 40/40 [==============================] - 20s 498ms/step - loss: 0.6883 - accuracy: 0.5411 - val_loss: 0.6834 - val_accuracy: 0.5641
#
# Epoch 00071: val_accuracy did not improve from 0.60952
# Epoch 72/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.6900 - accuracy: 0.5454 - val_loss: 0.6830 - val_accuracy: 0.5663
#
# Epoch 00072: val_accuracy did not improve from 0.60952
# Epoch 73/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.6884 - accuracy: 0.5433 - val_loss: 0.6826 - val_accuracy: 0.5675
#
# Epoch 00073: val_accuracy did not improve from 0.60952
# Epoch 74/500
# 40/40 [==============================] - 20s 499ms/step - loss: 0.6864 - accuracy: 0.5521 - val_loss: 0.6823 - val_accuracy: 0.5668
#
# Epoch 00074: val_accuracy did not improve from 0.60952
# Epoch 75/500
# 40/40 [==============================] - 20s 497ms/step - loss: 0.6846 - accuracy: 0.5549 - val_loss: 0.6821 - val_accuracy: 0.5682
#
# Epoch 00075: val_accuracy did not improve from 0.60952
# Epoch 76/500
# 40/40 [==============================] - 20s 499ms/step - loss: 0.6862 - accuracy: 0.5477 - val_loss: 0.6818 - val_accuracy: 0.5687
#
# Epoch 00076: val_accuracy did not improve from 0.60952
# Epoch 00076: early stopping
# CPU times: user 20min 5s, sys: 5min 24s, total: 25min 29s
# Wall time: 25min 16s

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist.history['loss']) + 1)

plt.figure(figsize = (18, 6))

for num, value in enumerate(['loss', 'accuracy']):
  plt.subplot(1, 2, num + 1)
  plt.plot(epochs, Hist.history['{}'.format(value)])
  plt.plot(epochs, Hist.history['val_{}'.format(value)])
  plt.title('Training & Validation {}'.format(value.title()))
  plt.xlabel('Epochs')
  plt.ylabel('{}'.format(value.title()))
  plt.legend(['Training Loss', 'Validation Loss'])
  plt.grid()
plt.show()

# %%
comment_model.evaluate(data_test, labels_test)
# Out:
# 142/142 [==============================] - 16s 111ms/step - loss: 0.6684 - accuracy: 0.6277
# [0.6684361100196838, 0.6276854872703552]

# %%
from keras.models import load_model

# %%
loaded_model = load_model('/content/drive/MyDrive/Colab Notebooks/project/best_comment_model.h5')

loaded_model.evaluate(data_test, labels_test)
# Out:
# 142/142 [==============================] - 36s 33ms/step - loss: 0.7558 - accuracy: 0.5595
# [0.7557763457298279, 0.5594684481620789]
